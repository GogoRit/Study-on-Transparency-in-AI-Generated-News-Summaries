# %%
# !pip install pandas
from google.colab import drive
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/random_selected_articles.csv')

# Display the first few rows of the dataframe
print(df.head())
# Out:
#                                                title  \
# 0     Abortion After the Pandemic - Dissent Magazine
# 1  Fertility and diet: Is there a connection? - H...
# 2  Arkansas Legislators’ Attack on Abortion is Un...
# 3  \n    Trump criticized by rivals for calling 6...
# 4        Pro-life progressives aren’t rare  - al.com
#
#                                      cleaned_article
# 0  Abortion After the Pandemic - Dissent Magazine...
# 1  Fertility and diet Is there a connection? - Ha...
# 2  Arkansas Legislators Attack on Abortion is Unc...
# 3  Trump criticized by rivals for calling 6-week ...
# 4  Pro-life progressives arent rare - al.com Skip...
